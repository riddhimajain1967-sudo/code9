# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# 1. Generate a more complex synthetic dataset with some noise
np.random.seed(42)
X_data = np.random.rand(100, 1) * 10  # 100 data points between 0 and 10
y_data = 2 * X_data + 1 + np.random.randn(100, 1) * 2 # y = 2x + 1 + noise

print("Generated X_data shape:", X_data.shape)
print("Generated y_data shape:", y_data.shape)

# %% [markdown]
# Let's visualize our generated data to understand its distribution before training the model.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_data, y_data, color='blue', label='Generated Data Points', alpha=0.7)
plt.title('Generated Data for Linear Regression')
plt.xlabel('X (Independent Variable)')
plt.ylabel('y (Dependent Variable)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### 2. Split the Data into Training and Testing Sets
#
# It's crucial to split data to evaluate the model's performance on unseen data, preventing overfitting.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=42)

print(f"Training data size: {len(X_train)} samples")
print(f"Testing data size: {len(X_test)} samples")

# %% [markdown]
# ### 3. Create and Train the Linear Regression Model
#
# We instantiate the `LinearRegression` model and fit it to our training data.

# %%
# Create a Linear Regression model object
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Print the learned coefficients
print(f"Learned Slope (Coefficient): {model.coef_[0][0]:.3f}")
print(f"Learned Intercept: {model.intercept_[0]:.3f}")

# %% [markdown]
# ### 4. Make Predictions on the Test Set
#
# Once the model is trained, we use it to predict `y` values for our unseen `X_test` data.

# %%
y_pred = model.predict(X_test)

print("First 5 actual test values:", y_test[:5].flatten())
print("First 5 predicted test values:", y_pred[:5].flatten())

# %% [markdown]
# ### 5. Evaluate the Model Performance
#
# We use common regression metrics like Mean Squared Error (MSE) and R-squared ($R^2$) to assess how well our model performs.

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate R-squared (coefficient of determination)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.3f}")
print(f"R-squared (R2 Score): {r2:.3f}")

# %% [markdown]
# ### 6. Visualize the Regression Line
#
# Finally, we plot the original data points along with the fitted regression line to visually inspect the model's fit.

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_test, y_test, color='blue', label='Actual Test Data', alpha=0.7)
plt.plot(X_test, y_pred, color='red', linewidth=3, label='Regression Line (Predicted)', alpha=0.8)
plt.title('Linear Regression: Actual vs. Predicted Values')
plt.xlabel('X (Independent Variable)')
plt.ylabel('y (Dependent Variable)')
plt.grid(True)
plt.legend()
plt.show()
